# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator

import aplpy
from skimage.feature import peak_local_max
from scipy.stats import chi2, norm

from astropy.wcs import WCS
from astropy.io import fits
from astropy import units as u
from astropy.coordinates import SkyCoord, Angle, search_around_sky
from astropy.wcs.utils import skycoord_to_pixel, pixel_to_skycoord
from astropy.nddata.utils import Cutout2D
from astropy.table import Table, vstack
from astropy.time import Time

# %%
import glob
import os

# %%
src_name = "J074249.01-282244.23"
sbid = 50660
beam = 28
folder = f"/import/eve/fast_imaging/SB{sbid}/images"

# %%
imagelist = []
for size in ["?", "??", "???", "????"]:
    tmp = glob.glob(os.path.join(folder, f'*{beam}_{size}.fits'))
    tmp.sort()
    imagelist += tmp

# print(imagelist)

# %%
ind = 55
image = imagelist[ind]
print(image)
# Out:
# /import/eve/fast_imaging/SB50660/images/SB50660_beam28_57.fits

# %%
src = SkyCoord(src_name, unit=(u.hourangle, u.degree))
src
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (115.70420833, -28.37895278)>

# %%
def save_fits_cutout(src_name, image, radius=5):
    
    src = SkyCoord(src_name, unit=(u.hourangle, u.degree))
    # open the fits
    hdu = fits.open(image)[0]
    # get the fits data (drop-out extra dimensions)
    data = hdu.data.squeeze()
    # get wcs frame
    wcs = WCS(header=hdu.header, naxis=2)
    print(wcs)
    # generate cutout
    cutout = Cutout2D(data, 
                      position=src, 
                      size=radius*u.arcmin, 
                      wcs=wcs
                     )

    # Put the cutout image in the FITS HDU
    hdu.data = cutout.data

    # Update the FITS header with the cutout WCS
    hdu.header.update(cutout.wcs.to_header())

    # Write the cutout to a new FITS file
    cutout_filename = 'example_cutout.fits'
    hdu.writeto(cutout_filename, overwrite=True)

    return cutout

# %%
def save_fits_cube(src_name, imagelist, radius=5):
    """Generate a fits cube containing images cutout in given position. 
    src: 
        astropy Skycoord object. 
    imagelist: 
        A list of short FITS images, in correct order. 
    radius:
        unit of arcmin, the cutout size
    """
    
    # get the source position 
    src = SkyCoord(src_name, unit=(u.hourangle, u.degree))
    print("Get source position ({}, {})...".format(src.ra.degree, src.dec.degree))

    final_data = []
    
    # generate each frame
    for i, image in enumerate(imagelist):
        print("Processing image number %s/%s" % (i, len(imagelist)))
        
        # open the fits
        hdu = fits.open(image)[0]
        # get the fits data (drop-out extra dimensions)
        data = hdu.data.squeeze()
        # get wcs frame
        wcs = WCS(header=hdu.header, naxis=2)
        # generate cutout
        cutout = Cutout2D(data, 
                          position=src, 
                          size=radius*u.arcmin, 
                          wcs=wcs)
        # Put the cutout image in the FITS HDU
        final_data.append(cutout.data)

        if i == 0:
            final_header = cutout.wcs.to_header()
            final_hdu = hdu
    
    # Update the FITS header with the cutout WCS
    final_hdu.header.update(final_header)

    # save the data cube to FITS
    final_hdu.data = np.array(final_data)

    # Write the cutout to a new FITS file
    cutout_filename = 'example_cube.fits'
    final_hdu.writeto(cutout_filename, overwrite=True)

    return final_hdu

# %%
cutout = save_fits_cutout(src, image)
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---SIN'  'DEC--SIN'
# CRVAL : 116.0649258267  -27.75440551077
# CRPIX : 1401.0  1401.0
# PC1_1 PC1_2  : 1.0  0.0
# PC2_1 PC2_2  : 0.0  1.0
# CDELT : -0.0006944444444444  0.0006944444444444
# NAXIS : 2800  2800  1  1
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
cutout.data.shape
# Out:
# (120, 120)

# %%
cutout.wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---SIN'  'DEC--SIN'
# CRVAL : 116.0649258267  -27.75440551077
# CRPIX : -396.0  961.0
# PC1_1 PC1_2  : 1.0  0.0
# PC2_1 PC2_2  : 0.0  1.0
# CDELT : -0.0006944444444444  0.0006944444444444
# NAXIS : 120  120

# %%
hdu = save_fits_cube(src_name, imagelist)
# Out:
# Get source position (115.70420833333333, -28.37895277777778)...
# Processing image number 0/69
# Processing image number 1/69
# Processing image number 2/69
# Processing image number 3/69
# Processing image number 4/69
# Processing image number 5/69
# Processing image number 6/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 7/69
# Processing image number 8/69
# Processing image number 9/69
# Processing image number 10/69
# Processing image number 11/69
# Processing image number 12/69
# Processing image number 13/69
# Processing image number 14/69
# Processing image number 15/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 16/69
# Processing image number 17/69
# Processing image number 18/69
# Processing image number 19/69
# Processing image number 20/69
# Processing image number 21/69
# Processing image number 22/69
# Processing image number 23/69
# Processing image number 24/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 25/69
# Processing image number 26/69
# Processing image number 27/69
# Processing image number 28/69
# Processing image number 29/69
# Processing image number 30/69
# Processing image number 31/69
# Processing image number 32/69
# Processing image number 33/69
# Processing image number 34/69
# Processing image number 35/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 36/69
# Processing image number 37/69
# Processing image number 38/69
# Processing image number 39/69
# Processing image number 40/69
# Processing image number 41/69
# Processing image number 42/69
# Processing image number 43/69
# Processing image number 44/69
# Processing image number 45/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 46/69
# Processing image number 47/69
# Processing image number 48/69
# Processing image number 49/69
# Processing image number 50/69
# Processing image number 51/69
# Processing image number 52/69
# Processing image number 53/69
# Processing image number 54/69
# Processing image number 55/69
# Processing image number 56/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Processing image number 57/69
# Processing image number 58/69
# Processing image number 59/69
# Processing image number 60/69
# Processing image number 61/69
# Processing image number 62/69
# Processing image number 63/69
# Processing image number 64/69
# Processing image number 65/69
# Processing image number 66/69
# Processing image number 67/69
# Processing image number 68/69
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   116.658800 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.704100 from OBSGEO-[XYZ].
# Set OBSGEO-H to      121.995 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]

# %%
hdu.header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    3
# NAXIS1  =                  120
# NAXIS2  =                  120
# NAXIS3  =                   69
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   4.568852318658E-03
# BMIN    =   4.058241844177E-03
# BPA     =   8.230576324463E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'VAST_0741-25'
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03 / [yr] Equinox of equatorial coordinates
# RADESYS = 'FK5     '           / Equatorial coordinate system
# LONPOLE =   1.800000000000E+02 / [deg] Native longitude of celestial pole
# LATPOLE =  -2.775440551077E+01 / [deg] Native latitude of celestial pole
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'           / Right ascension, orthographic/synthesis project
# CRVAL1  =   1.160649258267E+02 / [deg] Coordinate value at reference point
# CDELT1  =  -6.944444444444E-04 / [deg] Coordinate increment at reference point
# CRPIX1  =               -396.0 / Pixel coordinate of reference point
# CUNIT1  = 'deg     '           / Units of coordinate increment and value
# CTYPE2  = 'DEC--SIN'           / Declination, orthographic/synthesis projection
# CRVAL2  =  -2.775440551077E+01 / [deg] Coordinate value at reference point
# CDELT2  =   6.944444444444E-04 / [deg] Coordinate increment at reference point
# CRPIX2  =                961.0 / Pixel coordinate of reference point
# CUNIT2  = 'deg     '           / Units of coordinate increment and value
# CTYPE3  = 'FREQ    '
# CRVAL3  =   8.875789949756E+08
# CDELT3  =   2.880286394195E+08
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'Hz      '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00 / SIN projection parameter
# PV2_2   =   0.000000000000E+00 / SIN projection parameter
# RESTFRQ =   8.875789949756E+08 / [Hz] Line rest frequency
# SPECSYS = 'LSRK    '           / Reference frame of spectral coordinates
# ALTRVAL =  -0.000000000000E+00 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ASKAP   '
# OBSERVER= '        '
# DATE-OBS= '2023-06-22T04:36:27.510142' / ISO-8601 time of observation
# TIMESYS = 'UTC     '           / Time scale
# OBSRA   =   1.160649258267E+02
# OBSDEC  =  -2.775440551077E+01
# OBSGEO-X=  -2.558266717765E+06 / [m] observatory X-coordinate
# OBSGEO-Y=   5.095672176508E+06 / [m] observatory Y-coordinate
# OBSGEO-Z=  -2.849020838078E+06 / [m] observatory Z-coordinate
# INSTRUME= 'ASKAP   '
# DISTANCE=   0.000000000000E+00
# MPIPROCS=                    1
# CHNCHNKS=                    1
# MEMREQ  =        6.6741943E-01
# MEMAVAIL=        1.7030530E+02
# USEWEIGH=                    F
# DATE    = '2024-01-22T02:07:47.687582' /Date FITS file was written
# ORIGIN  = 'CASA 6.6.0-20 CASAtools:v1.0.0'
# WCSAXES =                    2 / Number of coordinate axes
# MJDREF  =                  0.0 / [d] MJD of fiducial time
# MJD-OBS =      60117.191985071 / [d] MJD of observation
# HISTORY CASA START LOGTABLE
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY taskname=tclean
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY version: 6.6.0-20 CASAtools:v1.0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY vis         = "/import/eve/fast_imaging/SB50660/data/scienceData.VAST_07
# HISTORY >41-25.SB50660.VAST_0741-25.beam28_averaged_cal.leakage.ms.corrected"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY selectdata  = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY field       = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY spw         = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY timerange   = "2023/06/22/04:36:23~2023/06/22/04:36:33"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY uvrange     = ">200m"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY antenna     = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY scan        = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY observation = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY intent      = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY datacolumn  = "corrected"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY imagename   = "SB50660_beam28_2"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY imsize      = 2800
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY cell        = ['2.5arcsec']
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY phasecenter = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY stokes      = "I"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY projection  = "SIN"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY startmodel  = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY specmode    = "mfs"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY reffreq     = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY nchan       = -1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY start       = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY width       = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY outframe    = "LSRK"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY veltype     = "radio"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY restfreq    = []
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY interpolation = "linear"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY perchanweightdensity = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY gridder     = "widefield"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY facets      = 2
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY psfphasecenter = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY wprojplanes = -1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY vptable     = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY mosweight   = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY aterm       = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY psterm      = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY wbawp       = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY conjbeams   = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY cfcache     = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY usepointing = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY computepastep = 360.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY rotatepastep = 360.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY pointingoffsetsigdev = []
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY pblimit     = -0.2
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY normtype    = "flatnoise"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY deconvolver = "multiscale"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY scales      = [0]
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY nterms      = 1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY smallscalebias = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY fusedthreshold = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY largestscale = -1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY restoration = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY restoringbeam = []
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY pbcor       = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY outlierfile = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY weighting   = "briggs"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY robust      = 0.5
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY noise       = "1.0Jy"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY npixels     = 0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY uvtaper     = []
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY niter       = 0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY gain        = 0.1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY threshold   = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY nsigma      = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY cycleniter  = -1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY cyclefactor = 1.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY minpsffraction = 0.02
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY maxpsffraction = 0.8
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY interactive = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY nmajor      = -1
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY fullsummary = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY usemask     = "user"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY mask        = ""
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY pbmask      = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY sidelobethreshold = 3.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY noisethreshold = 5.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY lownoisethreshold = 1.5
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY negativethreshold = 0.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY smoothfactor = 1.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY minbeamfrac = 0.3
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY cutthreshold = 0.01
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY growiterations = 75
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY dogrowprune = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY minpercentchange = -1.0
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY verbose     = False
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY fastnoise   = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY restart     = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY savemodel   = "none"
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY calcres     = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY calcpsf     = True
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY psfcutoff   = 0.35
# HISTORY 2024-01-22T02:07:46 INFO SRCCODE='::tclean'
# HISTORY parallel    = False
# HISTORY CASA END LOGTABLE
